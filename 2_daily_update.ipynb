# %%
import util
import datetime


project = util.connect_to_hopsworks_project()

fs = util.create_fs(project)

cities = {"stockholm":[59.3294,18.0687], "goteborg":[57.7072,11.9668]}

keys = list(cities.keys())

price_fg, weather_1_fg, weather_2_fg = util.get_fgs(fs,keys[0],keys[1])

weather_df_1 = util.forecast_weather(cities[keys[0]][0],cities[keys[0]][1],keys[0])
weather_df_2 = util.forecast_weather(cities[keys[1]][0],cities[keys[1]][1],keys[1])




today = datetime.datetime.now() - datetime.timedelta(days=0)
yesterday = today - datetime.timedelta(days=1)



price_df = util.get_historic_price(price_fg,yesterday,yesterday)

util.weather_insert(weather_1_fg,weather_df_1)
util.weather_insert(weather_2_fg,weather_df_2)

util.price_insert(price_fg,price_df)
# Out:
# 2026-01-09 11:37:56,513 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2026-01-09 11:37:56,522 INFO: Initializing external client
# 2026-01-09 11:37:56,524 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-09 11:37:57,977 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1326229
# Coordinates: 59.32889938354492°N 18.072357177734375°E
# Elevation: 24.0 m asl
# Timezone difference to GMT+0: 0s
# Coordinates: 57.7052116394043°N 11.973724365234375°E
# Elevation: 9.0 m asl
# Timezone difference to GMT+0: 0s
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.07s)
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: weather_stockholm_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1326229/jobs/named/weather_stockholm_1_offline_fg_materialization/executions
# 2026-01-09 11:38:18,197 INFO: Waiting for execution to finish. Current state: INITIALIZING. Final status: UNDEFINED
# 2026-01-09 11:38:21,432 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-09 11:38:24,668 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-09 11:40:27,122 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-09 11:40:27,311 INFO: Waiting for log aggregation to finish.
# 2026-01-09 11:40:53,028 INFO: Execution finished successfully.
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: weather_goteborg_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1326229/jobs/named/weather_goteborg_1_offline_fg_materialization/executions
# 2026-01-09 11:41:07,684 INFO: Waiting for execution to finish. Current state: INITIALIZING. Final status: UNDEFINED
# 2026-01-09 11:41:10,991 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-09 11:41:14,201 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-09 11:43:20,021 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-09 11:43:20,194 INFO: Waiting for log aggregation to finish.
# 2026-01-09 11:43:42,472 INFO: Execution finished successfully.
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: price_swedene3_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1326229/jobs/named/price_swedene3_1_offline_fg_materialization/executions
# 2026-01-09 11:43:57,540 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-09 11:44:00,745 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-09 11:45:56,447 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-09 11:45:56,612 INFO: Waiting for log aggregation to finish.
# 2026-01-09 11:46:18,733 INFO: Execution finished successfully.
